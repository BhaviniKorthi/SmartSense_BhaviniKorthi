# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
data1 = pd.read_csv('Data/CMO_MSP_Mandi.csv')
data1.rename(columns = {"commodity": "Commodity", "year": "Year" }, inplace= True)
data1 ["Commodity"] = data1["Commodity"].str.upper()
data1.head()
# Out:
#          Commodity  Year          Type  msprice  msp_filter
# 0   PADDY-UNHUSKED  2012  Kharif Crops   1250.0           1
# 1  RICE(PADDY-HUS)  2012  Kharif Crops   1280.0           1
# 2     JOWAR_HYBRID  2012  Kharif Crops   1500.0           1
# 3    SORGUM(JAWAR)  2012  Kharif Crops   1520.0           1
# 4            BAJRI  2012  Kharif Crops   1175.0           1

# %%
data2 = pd.read_csv('Data/Monthly_data_cmo.csv')
data2 ["Commodity"] = data2["Commodity"].str.upper()
data2.head()
# Out:
#          APMC      Commodity  Year  Month  arrivals_in_qtl  min_price  \
# 0  Ahmednagar          BAJRI  2015  April               79       1406
# 1  Ahmednagar          BAJRI  2016  April              106       1788
# 2  Ahmednagar  WHEAT(HUSKED)  2015  April             1253       1572
# 3  Ahmednagar  WHEAT(HUSKED)  2016  April              387       1750
# 4  Ahmednagar  SORGUM(JAWAR)  2015  April             3825       1600
#
#    max_price  modal_price     date district_name   state_name
# 0       1538         1463  2015-04    Ahmadnagar  Maharashtra
# 1       1925         1875  2016-04    Ahmadnagar  Maharashtra
# 2       1890         1731  2015-04    Ahmadnagar  Maharashtra
# 3       2220         1999  2016-04    Ahmadnagar  Maharashtra
# 4       2200         1900  2015-04    Ahmadnagar  Maharashtra

# %%
final_data = pd.merge(data1, data2, on=['Commodity', 'Year'])
final_data.head()
# Out:
#         Commodity  Year          Type  msprice  msp_filter    APMC      Month  \
# 0  PADDY-UNHUSKED  2014  Kharif Crops   1360.0           1   Akole   December
# 1  PADDY-UNHUSKED  2014  Kharif Crops   1360.0           1   Akole   November
# 2  PADDY-UNHUSKED  2014  Kharif Crops   1360.0           1   Akole    October
# 3  PADDY-UNHUSKED  2014  Kharif Crops   1360.0           1   Akole  September
# 4  PADDY-UNHUSKED  2014  Kharif Crops   1360.0           1  Pavani   December
#
#    arrivals_in_qtl  min_price  max_price  modal_price     date district_name  \
# 0              346       1400       1800         1625  2014-12    Ahmadnagar
# 1              204       1450       1800         1625  2014-11    Ahmadnagar
# 2              103       1425       1900         1669  2014-10    Ahmadnagar
# 3              119       1450       1900         1681  2014-09    Ahmadnagar
# 4             1424       1731       1821         1781  2014-12      Bhandara
#
#     state_name
# 0  Maharashtra
# 1  Maharashtra
# 2  Maharashtra
# 3  Maharashtra
# 4  Maharashtra

# %%
final_data['Date'] = pd.to_datetime(final_data['date'])
final_data['Month'] = final_data['Date'].dt.month
final_data['Season'] = (final_data['Month'] % 12 + 3) 
final_data.head()
# Out:
#         Commodity  Year          Type  msprice  msp_filter    APMC  Month  \
# 0  PADDY-UNHUSKED  2014  Kharif Crops   1360.0           1   Akole     12
# 1  PADDY-UNHUSKED  2014  Kharif Crops   1360.0           1   Akole     11
# 2  PADDY-UNHUSKED  2014  Kharif Crops   1360.0           1   Akole     10
# 3  PADDY-UNHUSKED  2014  Kharif Crops   1360.0           1   Akole      9
# 4  PADDY-UNHUSKED  2014  Kharif Crops   1360.0           1  Pavani     12
#
#    arrivals_in_qtl  min_price  max_price  modal_price     date district_name  \
# 0              346       1400       1800         1625  2014-12    Ahmadnagar
# 1              204       1450       1800         1625  2014-11    Ahmadnagar
# 2              103       1425       1900         1669  2014-10    Ahmadnagar
# 3              119       1450       1900         1681  2014-09    Ahmadnagar
# 4             1424       1731       1821         1781  2014-12      Bhandara
#
#     state_name       Date  Season
# 0  Maharashtra 2014-12-01       3
# 1  Maharashtra 2014-11-01      14
# 2  Maharashtra 2014-10-01      13
# 3  Maharashtra 2014-09-01      12
# 4  Maharashtra 2014-12-01       3

# %%
features_for_Prediction = ['Commodity', 'Year', 'Type', 'APMC', 'Month','arrivals_in_qtl', 'min_price', 'max_price', 'district_name', 'state_name', 'Season']
target_to_Predict = 'modal_price'
# features_for_Prediction = ['Year', 'Month','arrivals_in_qtl', 'min_price', 'max_price','Season']
categorical_columns = ["Commodity", "Type", "APMC", "district_name", "state_name"]
X = final_data[features_for_Prediction]
y = final_data[target_to_Predict]

for i in categorical_columns:
    val = X[i].unique()
    arr = [j for j in range(len(val))]
    X[i].replace(val, arr, inplace=True)


X
# Out:
# C:\Users\C2IN\AppData\Local\Temp\ipykernel_17460\2019644321.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[i].replace(val, arr, inplace=True)
#        Commodity  Year  Type  APMC  Month  arrivals_in_qtl  min_price  \
# 0              0  2014     0     0     12              346       1400
# 1              0  2014     0     0     11              204       1450
# 2              0  2014     0     0     10              103       1425
# 3              0  2014     0     0      9              119       1450
# 4              0  2014     0     1     12             1424       1731
# ...          ...   ...   ...   ...    ...              ...        ...
# 20854         18  2016     2   242      7             1962        308
# 20855         18  2016     2   242      6             5387        300
# 20856         18  2016     2   242      3             3205        300
# 20857         18  2016     2   242      5             5700        296
# 20858         18  2016     2   242     11              170        200
#
#        max_price  district_name  state_name  Season
# 0           1800              0           0       3
# 1           1800              0           0      14
# 2           1900              0           0      13
# 3           1900              0           0      12
# 4           1821              1           0       3
# ...          ...            ...         ...     ...
# 20854        515             14           0      10
# 20855        972             14           0       9
# 20856        500             14           0       6
# 20857        571             14           0       8
# 20858        500             14           0      14
#
# [20859 rows x 11 columns]

# %%
y

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
X_train

# %%
model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

df = pd.DataFrame({"original":y_test, "Predicted":y_pred})
# print(y_pred)
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred) 
rmse = mse ** 0.5
print(mse)
print(f'Root Mean Squared Error: {rmse}')
df
